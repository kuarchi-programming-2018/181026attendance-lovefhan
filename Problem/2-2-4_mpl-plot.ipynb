# %% [markdown]
# # ライブラリの`import`を用いる
# ## matplotlibを使ってグラフをプロット

# %% [markdown]
# まずはデータを読み込み，それをX, Yのデータにして返す関数を作りましょう。
# csv とはcomma separated valuesです。テキストで開いてみればわかります。エクセルでも開けます。

# %% [markdown]
# matplotlibを用いてデータを散布図にプロットする関数を作成します。

# %%
import matplotlib.pyplot as plt
% matplotlib inline
#  % matplotlib inlineはjupyter notebookでmatplotlibを行内に表示するためのおまじない

# %%
import numpy as np
x = np.arange(-3., 3, 0.1)
y = np.sin(x)
plt.title("title")
plt.xlabel("X-LABEL")
plt.ylabel("Y-LABEL")
plt.plot(x, y)
plt.show()

# %%
def draw_graph(X, Y, title, xlabel, ylabel):
    # ここに描画するプログラムを書く。
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.plot(X, Y)
    plt.show()  # グラフの描画

# %% [markdown]
# では，データを読み込んで描画して見ましょう。

# %%
import csv
def read_data(file_name):
    reader = csv.reader(open(file_name, 'r'))
    X = []
    Y = []
    for row in reader:
        X.append(float(row[0]))
        Y.append(float(row[1]))
    return X, Y  # データを返す

# %%
file_name = 'data3.csv'  # ファイル名
x, y = read_data(file_name)
print(x)
print(y)
# 関数read_dataによりデータを取得
# タイトル，ラベル
title = "data from CSV"
xl = "x values"
yl = "y values"
draw_graph(x, y, title, xl, yl) # 関数draw_graphによりグラフ描画
# Out:
# [0.3, 1.02, 2.5, 3.2, 3.97, 5.4, 6.7, 7.1, 8.4, 9.6, -4.0, -6.0]
# [5.01, 6.35, 7.4, 7.3, 7.66, 4.2, 2.1, 1.2, 9.2, 5.4, 10.0, -3.0]
